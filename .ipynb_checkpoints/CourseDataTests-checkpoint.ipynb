# %%
# %load_ext sql

# %%
# %%sql
# sqlite:///../FP/CourseData-Copy1.db
# Out:
# 'Connected: @../FP/CourseData-Copy1.db'

# %%
# %%sql
# SELECT COUNT(*) AS Count
# FROM COURSE_OFFERING;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [(15955,)]

# %%
# %%sql
# SELECT COUNT(*) AS Count FROM COURSE_MEETING;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [(311159,)]

# %%
# %%sql
# SELECT COUNT(*) AS Count FROM INSTRUCTOR;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [(1105,)]

# %%
# %%sql
# SELECT COUNT(*) AS Count FROM CATALOG_DESC;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [(4440,)]

# %%
# %%sql
# SELECT DISTINCT (primary_instructor) AS Teacher, COUNT(section) AS No_Sections
# FROM COURSE_OFFERING
# JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
# WHERE act > 10 AND term = 'Spring2019'
# GROUP BY primary_instructor
# ORDER BY No_sections DESC
# LIMIT 10;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Nancy A.  Moriber', 6),
#  ('Anderson   Weekes', 4),
#  ('Anthony J.  DeCristofaro', 4),
#  ('Ayanna   Eastman', 4),
#  ('Bidyut B.  Das', 4),
#  ('Christine   Earls', 4),
#  ('Christine R.  Rodriguez', 4),
#  ('Cynthia A.  Bautista', 4),
#  ('Danielle E.  Hall', 4),
#  ('Djedjiga   Belfadel', 4)]

# %%
# %%sql
# SELECT primary_instructor AS Teacher, title AS Class, day, start, end
# FROM COURSE_OFFERING
# JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
# JOIN COURSE_MEETING ON (COURSE_OFFERING.course_offering_id=COURSE_MEETING.course_offering_id)
# WHERE COURSE_OFFERING.CRN = '39006' AND COURSE_OFFERING.term = 'Spring2019';
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-01-29T18:30:00', '2019-01-29T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-02-05T18:30:00', '2019-02-05T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-02-12T18:30:00', '2019-02-12T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-02-26T18:30:00', '2019-02-26T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-03-05T18:30:00', '2019-03-05T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-03-12T18:30:00', '2019-03-12T21:30:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-01-29T09:00:00', '2019-01-29T16:00:00'),
#  ('Christopher L.  Huntley', 'Databases for Business Analytics', 'T', '2019-02-05T09:00:00', '2019-02-05T16:00:00'),
# ...

# %%
# %%sql
# SELECT program_name, AVG(act) AS Average_Size
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_OFFERING.CRN=COURSE_MEETING.CRN AND COURSE_OFFERING.term=COURSE_MEETING.term)
# WHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10
# GROUP BY program_name
# ORDER BY Average_Size DESC
# LIMIT 10;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [('Nursing', 37.450439146800505),
#  ('Applied Ethics', 29.608695652173914),
#  ('Accounting', 27.400452488687783),
#  ('Operations Management', 26.666666666666668),
#  ('Anthropology', 26.122222222222224),
#  ('Biology', 25.631296891747052),
#  ('Marketing', 25.601866251944013),
#  ('Classical Studies', 25.5),
#  ('Management', 24.924836601307188),
#  ('Sociology', 24.300531914893618)]

# %%
# %%sql
# SELECT DISTINCT CRN, title AS Class, primary_instructor AS Teacher, program_name, act AS Students, term AS Semester
# FROM COURSE_OFFERING
#     JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
# WHERE term = 'Summer2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Summer2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Accounting' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Taxation' AND act > 10;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [('58124', 'Issues in a Regulatory Reporting Environment', 'Stephen E.  Yost', 'Accounting', 28, 'Summer2018'),
#  ('58125', 'Issues in a Regulatory Reporting Environment', 'Stephen E.  Yost', 'Accounting', 24, 'Summer2018'),
#  ('58101', 'Accounting for Governments, Hospitals, and Universities', 'Milo W.  Peck', 'Accounting', 23, 'Summer2018'),
#  ('58102', 'Accounting for Governments, Hospitals, and Universities', 'Milo W.  Peck', 'Accounting', 23, 'Summer2018'),
#  ('58202', 'Accounting for Governments, Hospitals, and Universities', 'Milo W.  Peck', 'Accounting', 22, 'Summer2018'),
#  ('58103', 'Financial Statement Analysis', 'Lisa Suzanne  Haylon', 'Accounting', 23, 'Summer2018'),
#  ('58104', 'Financial Statement Analysis', 'Patricia M.  Poli', 'Accounting', 24, 'Summer2018'),
#  ('58203', 'Financial Statement Analysis', 'Patricia M.  Poli', 'Accounting', 20, 'Summer2018'),
# ...

# %%
# %%sql
# SELECT primary_instructor AS Teacher, COUNT(title) AS Classes
# FROM COURSE_OFFERING
#     JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
# WHERE term = 'Summer2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Summer2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Accounting' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Taxation' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Applied_Ethics' AND act > 10 AND primary_instructor = 'Joan L. Lee'
# OR term = 'Spring2019' AND program_name = 'Applied_Ethics' AND act > 10 AND primary_instructor = 'Joan L. Lee'
# GROUP BY primary_instructor
# ORDER BY Classes DESC;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Milo W.  Peck', 9),
#  ('Jo Ann   Drusbosky', 7),
#  ('Kathi M.  Mettler', 7),
#  ('Ahmed M.  Ebrahim', 6),
#  ('Bruce   Bradford', 6),
#  ('Scott M  Brenner', 6),
#  ('Joan L.  Lee', 5),
#  ('Lisa Suzanne  Haylon', 5),
#  ('Michael P.  Coyne', 5),
#  ('Arleen N.  Kardos', 4),
#  ('Patricia M.  Poli', 4),
#  ('Rebecca I.  Bloch', 4),
#  ('Dawn W  Massey', 3),
#  ('Kara E.  Hunter', 3),
#  ('Kristen   Tharrington', 3),
#  ('Stephen E.  Yost', 3),
#  ('Charles   Gill', 2),
#  ('Ira P.  Klein', 2),
#  ('Paul   Caster', 2),
#  ('David J.  Orticelli', 1),
#  ('David L.  Glinka', 1),
#  ('Jenna Marie  Allegretto', 1),
#  ('John L.  DeMelis', 1),
#  ('Richard   Hunter', 1),
#  ('Rob   Hornak', 1),
#  ('Stephanie   Miller', 1),
#  ('Victor E.  Hartman', 1)]

# %%
# %%sql
# SELECT primary_instructor AS Teacher, COUNT(title) AS Classes, COUNT(DISTINCT title) AS Preps
# FROM COURSE_OFFERING
#     JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
# WHERE term = 'Summer2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Summer2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Accounting' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Taxation' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Accounting' AND act > 10
# OR term = 'Spring2019' AND program_name = 'Taxation' AND act > 10
# OR term = 'Fall2018' AND program_name = 'Applied_Ethics' AND act > 10 AND primary_instructor = 'Joan L. Lee'
# OR term = 'Spring2019' AND program_name = 'Applied_Ethics' AND act > 10 AND primary_instructor = 'Joan L. Lee'
# GROUP BY primary_instructor
# ORDER BY Classes DESC;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [('Milo W.  Peck', 9, 4),
#  ('Jo Ann   Drusbosky', 7, 2),
#  ('Kathi M.  Mettler', 7, 5),
#  ('Ahmed M.  Ebrahim', 6, 3),
#  ('Bruce   Bradford', 6, 2),
#  ('Scott M  Brenner', 6, 3),
#  ('Joan L.  Lee', 5, 2),
#  ('Lisa Suzanne  Haylon', 5, 3),
#  ('Michael P.  Coyne', 5, 3),
#  ('Arleen N.  Kardos', 4, 2),
#  ('Patricia M.  Poli', 4, 2),
#  ('Rebecca I.  Bloch', 4, 3),
#  ('Dawn W  Massey', 3, 1),
#  ('Kara E.  Hunter', 3, 2),
#  ('Kristen   Tharrington', 3, 2),
#  ('Stephen E.  Yost', 3, 2),
#  ('Charles   Gill', 2, 1),
#  ('Ira P.  Klein', 2, 2),
#  ('Paul   Caster', 2, 1),
#  ('David J.  Orticelli', 1, 1),
#  ('David L.  Glinka', 1, 1),
#  ('Jenna Marie  Allegretto', 1, 1),
#  ('John L.  DeMelis', 1, 1),
#  ('Richard   Hunter', 1, 1),
#  ('Rob   Hornak', 1, 1),
#  ('Stephanie   Miller', 1, 1),
#  ('Victor E.  Hartman', 1, 1)]

# %%
# %%sql
# SELECT DISTINCT COUNT(title) AS Title, program_name AS Department
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
# WHERE term = 'Spring2019' AND act > 10
# OR term = 'Fall2018' AND act > 10
# OR term = 'Summer2018' AND act > 10
# GROUP BY program_name;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [(85, 'Accounting'),
#  (1, 'American Studies'),
#  (21, 'Anthropology'),
#  (35, 'Applied Ethics'),
#  (30, 'Art History'),
#  (1, 'Bioengineering'),
#  (117, 'Biology'),
#  (1, 'Black Studies'),
#  (20, 'Business'),
#  (75, 'Chemistry'),
#  (2, 'Chinese'),
#  (4, 'Classical Studies'),
#  (62, 'Communication'),
#  (5, 'Computer Engineering'),
#  (19, 'Computer Science'),
#  (17, 'Counseling'),
#  (65, 'Economics'),
#  (31, 'Education'),
#  (12, 'Educational Technology'),
#  (9, 'Electrical Engineering'),
#  (18, 'Engineering'),
#  (158, 'English'),
#  (21, 'English: Writing'),
#  (17, 'Family Therapy'),
#  (15, 'Film, Television, and Media Arts'),
#  (73, 'Finance'),
#  (13, 'French'),
#  (2, 'German'),
#  (2, 'Graphic Design'),
#  (5, 'Health Studies'),
#  (31, 'History'),
#  (10, 'Honors'),
#  (33, 'Information Systems'),
#  (1, 'Interior Design'),
#  (14, 'International Studies'),
#  (22, 'Italian'),
#  (3, 'Latin'),
#  (62, 'Management'),
# ...

# %%
# %%sql
# SELECT program_name AS Department, COUNT(DISTINCT location) AS Location
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (CATALOG_DESC.catalog_desc_id=COURSE_OFFERING.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_MEETING.course_offering_id=COURSE_OFFERING.course_offering_id)
# WHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10 AND location LIKE 'DSB%'
# OR COURSE_OFFERING.term = 'Fall2018' AND act > 10 AND location LIKE 'DSB%'
# OR COURSE_OFFERING.term = 'Summer2018' AND act > 10 AND location LIKE 'DSB%'
# GROUP BY program_name;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Accounting', 12),
#  ('Applied Ethics', 3),
#  ('Business', 6),
#  ('Computer Science', 1),
#  ('Finance', 12),
#  ('Information Systems', 8),
#  ('International Studies', 1),
#  ('Management', 10),
#  ('Marketing', 11),
#  ('Operations Management', 7),
#  ('Quantitative Analysis', 1),
#  ('Taxation', 4)]

# %%
# %%sql
# SELECT program_name AS Department, COUNT(DISTINCT location) AS Location
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (CATALOG_DESC.catalog_desc_id=COURSE_OFFERING.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_MEETING.course_offering_id=COURSE_OFFERING.course_offering_id)
# WHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10 AND location LIKE 'DSB%'
# GROUP BY program_name
# ORDER BY Location DESC;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Accounting', 12),
#  ('Finance', 11),
#  ('Marketing', 10),
#  ('Management', 8),
#  ('Business', 5),
#  ('Information Systems', 5),
#  ('Operations Management', 4),
#  ('Applied Ethics', 3),
#  ('Taxation', 2)]

# %%
# %%sql
# SELECT progam_name AS Department, COUNT(program_name), location
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (CATALOG_DESC.catalog_desc_id=COURSE_OFFERING.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_MEETING.course_offering_id=COURSE_OFFERING.course_offering_id)
# WHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10 AND location LIKE 'DSB%'
# GROUP BY location;
# Out:
#  * sqlite:///CourseData.db
# (sqlite3.OperationalError) no such column: progam_name [SQL: "SELECT progam_name AS Department, COUNT(program_name), location\nFROM COURSE_OFFERING\n    JOIN CATALOG_DESC ON (CATALOG_DESC.catalog_desc_id=COURSE_OFFERING.catalog_desc_id)\n    JOIN COURSE_MEETING ON (COURSE_MEETING.course_offering_id=COURSE_OFFERING.course_offering_id)\nWHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10 AND location LIKE 'DSB%'\nGROUP BY location;"] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
# SELECT COURSE_OFFERING.term, AVG(act) AS Average_Size_DSB_Class
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_OFFERING.CRN=COURSE_MEETING.CRN AND COURSE_OFFERING.term=COURSE_MEETING.term)
# WHERE COURSE_OFFERING.term = 'Spring2019' AND act > 10 AND location LIKE 'DSB%';
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Spring2019', 24.902574605032182)]

# %%
# %%sql
# SELECT COURSE_OFFERING.term, AVG(act) AS Average_Size_DSB_Class
# FROM COURSE_OFFERING
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
#     JOIN COURSE_MEETING ON (COURSE_OFFERING.CRN=COURSE_MEETING.CRN AND COURSE_OFFERING.term=COURSE_MEETING.term)
# WHERE act > 10 AND location LIKE 'DSB%'
# GROUP BY COURSE_OFFERING.term;
# Out:
#  * sqlite:///CourseData.db
# Done.
# [('Fall2017', 25.190072337241208),
#  ('Fall2018', 24.997569275644143),
#  ('Spring2018', 23.92589962121212),
#  ('Spring2019', 24.902574605032182),
#  ('Summer2018', 20.044897959183672),
#  ('Winter2018', 15.761904761904763)]

# %%
# %%sql
# SELECT INSTRUCTOR.instructor_id, primary_instructor, COUNT(title) AS Classes_Taught, COUNT(DISTINCT title) AS Distinct_Preps, program_name
# FROM COURSE_OFFERING
#     JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id)
#     JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id)
# WHERE term = 'Summer2018' AND act > 10
# OR term = 'Fall2018' AND act > 10
# OR term = 'Spring2019' AND act > 10
# GROUP BY primary_instructor
# ORDER BY Classes_Taught DESC
# LIMIT 10;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [(420, 'Nancy A.  Moriber', 15, 14, 'Nursing', 'Summer2018'),
#  (52, 'Anthony J.  DeCristofaro', 11, 4, 'Biology', 'Summer2018'),
#  (457, 'Bidyut B.  Das', 10, 5, 'Physics', 'Summer2018'),
#  (51, 'Christine   Earls', 10, 5, 'Nursing', 'Summer2018'),
#  (698, 'Christine R.  Rodriguez', 10, 3, 'Biology', 'Summer2018'),
#  (638, 'Michael Walden  Creane', 10, 7, 'Psychology', 'Summer2018'),
#  (380, 'Katherine Marie  Saracino', 9, 5, 'Nursing', 'Summer2018'),
#  (9, 'Milo W.  Peck', 9, 4, 'Accounting', 'Summer2018'),
#  (111, 'Qin   Zhang', 9, 6, 'Communication', 'Summer2018'),
#  (70, 'Sharlene A.  McEvoy', 9, 3, 'Business', 'Summer2018')]

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("sqlite:///../FP/CourseData-Copy1.db")

# %%
with engine.connect() as conn, conn.begin():
    Teacher_Info = pd.read_sql("SELECT INSTRUCTOR.instructor_id, primary_instructor, COUNT(title) AS classes_taught, COUNT(DISTINCT title) AS distinct_preps, program_name FROM COURSE_OFFERING JOIN INSTRUCTOR ON (COURSE_OFFERING.instructor_id=INSTRUCTOR.instructor_id) JOIN CATALOG_DESC ON (COURSE_OFFERING.catalog_desc_id=CATALOG_DESC.catalog_desc_id) WHERE term = 'Summer2018' AND act > 10 OR term = 'Fall2018' AND act > 10 OR term = 'Spring2019' AND act > 10 GROUP BY primary_instructor ORDER BY Classes_Taught DESC;", conn)

# %%
with engine.connect() as conn, conn.begin():
    teacher_department = pd.read_sql('SELECT DISTINCT(COURSE_OFFERING.instructor_id), primary_instructor AS Teacher, program_name AS Department FROM COURSE_OFFERING JOIN INSTRUCTOR ON (INSTRUCTOR.instructor_id=COURSE_OFFERING.instructor_id) JOIN CATALOG_DESC ON (CATALOG_DESC.catalog_desc_id=COURSE_OFFERING.catalog_desc_id) ORDER BY COURSE_OFFERING.instructor_id;', conn)

# %%
Teacher_Info
# Out:
#      instructor_id              primary_instructor  classes_taught  \
# 0              420               Nancy A.  Moriber              15
# 1               52        Anthony J.  DeCristofaro              11
# 2              457                  Bidyut B.  Das              10
# 3               51               Christine   Earls              10
# 4              698         Christine R.  Rodriguez              10
# 5              638          Michael Walden  Creane              10
# 6              380       Katherine Marie  Saracino               9
# 7                9                   Milo W.  Peck               9
# 8              111                     Qin   Zhang               9
# 9               70             Sharlene A.  McEvoy               9
# 10             174                 Sonya R.  Huber               9
# 11             132  William F.  Vasquez Mazariegos               9
# 12             879               Anderson   Weekes               8
# ...

# %%
Teacher_Info.to_csv('teacher_info.csv', index=False)

# %%
# %%sql
# SELECT CRN, instructor_id, catalog_desc_id, course_offering_id, cap, act, rem
# FROM COURSE_OFFERING
# WHERE term = 'Summer2018' AND act > 10
# OR term = 'Fall2018' AND act > 10
# OR term = 'Spring2019' AND act > 10
# LIMIT 3;
# Out:
#  * sqlite:///../FP/CourseData-Copy1.db
# Done.
# [('58124', 10, 275, 12655, 25, 28, -3),
#  ('58125', 10, 275, 12656, 25, 24, 1),
#  ('58101', 9, 313, 12657, 22, 23, -1)]

# %%
with engine.connect() as conn, conn.begin():
    course_info = pd.read_sql("SELECT COURSE_OFFERING.CRN, instructor_id, catalog_desc_id, course_offering_id, location, cap, act, rem FROM COURSE_OFFERING JOIN COURSE_MEETING ON (COURSE_MEETING.course_offering_id=COURSE_OFFERING.course_offering_id) WHERE term = 'Summer2018' AND act > 10 OR term = 'Fall2018' AND act > 10 OR term = 'Spring2019' AND act > 10;", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# /opt/tljh/user/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: ambiguous column name: course_offering_id
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
course_info.to_csv('course_info.csv', index=False)

# %%
course_info
# Out:
#         CRN  instructor_id  catalog_desc_id  course_offering_id  cap  act  rem
# 0     58124             10            275.0               12655   25   28   -3
# 1     58125             10            275.0               12656   25   24    1
# 2     58101              9            313.0               12657   22   23   -1
# 3     58102              9            313.0               12658   20   23   -3
# 4     58202              9            313.0               12659   22   22    0
# 5     58103            772            365.0               12660   22   23   -1
# 6     58104             14            365.0               12661   22   24   -2
# 7     58203             14            365.0               12662   22   20    2
# 8     58419             18             92.0               12664   15   14    1
# 9     58219             23             28.0               12665   20   20    0
# 10    58081             34            163.0               12667   20   20    0
# ...
