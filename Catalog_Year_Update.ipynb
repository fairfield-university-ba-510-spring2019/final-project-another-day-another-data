# %%
import pandas as pd
import numpy as np

# %%
C = pd.read_csv('SourceData/Catalogs/CourseCatalog2017_2018.csv')

# %%
C.head()
# Out:
#   program_code   program_name catalog_id  \
# 0           AN  Asian Studies    AN 0301
# 1           AN  Asian Studies    AN 0310
# 2           BU       Business    BU 0211
# 3           BU       Business    BU 0220
# 4           BU       Business    BU 0311
#
#                                 course_title      credits           prereqs  \
# 0                          Independent Study  1-3 Credits               NaN
# 1                      Asian Studies Seminar    3 Credits               NaN
# 2              Legal Environment of Business    3 Credits  Junior standing.
# 3               Environmental Law and Policy    3 Credits               NaN
# 4  The Law of Contracts, Sales, and Property    3 Credits          BU 0211.
#
#   coreqs fees                                         attributes  \
# 0    NaN  NaN                                                NaN
# 1    NaN  NaN                                                NaN
# ...

# %%
C['catalog_year'] = '2017_2018'

# %%
C.head()
# Out:
#   program_code   program_name catalog_id  \
# 0           AN  Asian Studies    AN 0301
# 1           AN  Asian Studies    AN 0310
# 2           BU       Business    BU 0211
# 3           BU       Business    BU 0220
# 4           BU       Business    BU 0311
#
#                                 course_title      credits           prereqs  \
# 0                          Independent Study  1-3 Credits               NaN
# 1                      Asian Studies Seminar    3 Credits               NaN
# 2              Legal Environment of Business    3 Credits  Junior standing.
# 3               Environmental Law and Policy    3 Credits               NaN
# 4  The Law of Contracts, Sales, and Property    3 Credits          BU 0211.
#
#   coreqs fees                                         attributes  \
# 0    NaN  NaN                                                NaN
# 1    NaN  NaN                                                NaN
# ...

# %%
C2 = pd.read_csv('SourceData/Catalogs/CourseCatalog2018_2019.csv')

# %%
C2.head()
# Out:
#   program_code   program_name catalog_id  \
# 0           AN  Asian Studies    AN 0301
# 1           AN  Asian Studies    AN 0310
# 2           BU       Business    BU 0211
# 3           BU       Business    BU 0220
# 4           BU       Business    BU 0311
#
#                                 course_title      credits           prereqs  \
# 0                          Independent Study  1-3 Credits               NaN
# 1                      Asian Studies Seminar    3 Credits               NaN
# 2              Legal Environment of Business    3 Credits  Junior standing.
# 3               Environmental Law and Policy    3 Credits               NaN
# 4  The Law of Contracts, Sales, and Property    3 Credits          BU 0211.
#
#   coreqs fees                                         attributes  \
# 0    NaN  NaN                                                NaN
# 1    NaN  NaN                                                NaN
# ...

# %%
C2['catalog_year'] = '2018_2019'

# %%
C2.head()
# Out:
#   program_code   program_name catalog_id  \
# 0           AN  Asian Studies    AN 0301
# 1           AN  Asian Studies    AN 0310
# 2           BU       Business    BU 0211
# 3           BU       Business    BU 0220
# 4           BU       Business    BU 0311
#
#                                 course_title      credits           prereqs  \
# 0                          Independent Study  1-3 Credits               NaN
# 1                      Asian Studies Seminar    3 Credits               NaN
# 2              Legal Environment of Business    3 Credits  Junior standing.
# 3               Environmental Law and Policy    3 Credits               NaN
# 4  The Law of Contracts, Sales, and Property    3 Credits          BU 0211.
#
#   coreqs fees                                         attributes  \
# 0    NaN  NaN                                                NaN
# 1    NaN  NaN                                                NaN
# ...

# %%
Updated_Catalog_Year = pd.concat([C,C2])

# %%
Updated_Catalog_Year.to_csv('Updated_Catalog_Year.csv', index=False)

# %%
Updated_Catalog_Year
# Out:
#      program_code    program_name catalog_id  \
# 0              AN   Asian Studies    AN 0301
# 1              AN   Asian Studies    AN 0310
# 2              BU        Business    BU 0211
# 3              BU        Business    BU 0220
# 4              BU        Business    BU 0311
# 5              BU        Business    BU 0312
# 6              BU        Business    BU 0320
# 7              BU        Business    BU 0391
# 8              BL   Black Studies    BL 0101
# 9              BL   Black Studies    BL 0398
# 10            BEN  Bioengineering   BEN 0201
# 11            BEN  Bioengineering   BEN 0300
# 12            BEN  Bioengineering   BEN 0331
# 13            BEN  Bioengineering   BEN 0332
# 14            BEN  Bioengineering   BEN 0333
# 15            BEN  Bioengineering   BEN 0390
# 16            BEN  Bioengineering   BEN 0391
# 17             AR          Arabic    AR 0110
# 18             AR          Arabic    AR 0111
# 19             AR          Arabic    AR 0210
# ...
